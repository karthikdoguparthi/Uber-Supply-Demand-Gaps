# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikdoguparthi/Uber-Supply-Demand-Gaps/blob/main/Uber_SQL_Insights.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import duckdb
sql_file_path = '/content/insights.sql'
con = duckdb.connect(database=':memory:')

with open(sql_file_path, "r") as f:
    sql_script = f.read()

queries = [q.strip() for q in sql_script.split(';') if q.strip()]
for i, query in enumerate(queries, start=1):
    print(f"\nInsight {i-1}\n")
    result = con.execute(query).df()
    print(result)
# Out:
# Insight 0
#
#    Request id Pickup point Driver id          Status    Request Req_timestamp  \
# 0         619      Airport         1  Trip Completed 2016-07-11   11:51:00 AM
# 1         867      Airport         1  Trip Completed 2016-07-11    5:57:00 PM
# 2        1807         City         1  Trip Completed 2016-07-12    9:17:00 AM
# 3        2532      Airport         1  Trip Completed 2016-07-12    9:08:00 PM
# 4        3112         City         1  Trip Completed 2016-07-13    8:33:16 AM
# 5        3879      Airport         1  Trip Completed 2016-07-13    9:57:28 PM
# 6        4270      Airport         1  Trip Completed 2016-07-14    6:15:32 AM
# 7        5510      Airport         1  Trip Completed 2016-07-15    5:11:52 AM
# 8        6248         City         1  Trip Completed 2016-07-15    5:57:27 PM
# 9         267         City         2  Trip Completed 2016-07-11    6:46:00 AM
#
#   Day Category       Drop Drop_timestamp Travel Time Distance
# 0      Morning 2016-07-11     1:00:00 PM    01:09:00      Far
# 1      Evening 2016-07-11     6:47:00 PM    00:50:00   Medium
# 2      Morning 2016-07-12     9:58:00 AM    00:41:00   Medium
# 3        Night 2016-07-12    10:03:00 PM    00:55:00   Medium
# 4      Morning 2016-07-13     9:25:47 AM    00:52:31   Medium
# 5        Night 2016-07-13    10:28:59 PM    00:31:31   Medium
# 6      Morning 2016-07-14     7:13:15 AM    00:57:43   Medium
# 7      Morning 2016-07-15     6:07:52 AM    00:56:00   Medium
# 8      Evening 2016-07-15     6:50:51 PM    00:53:24   Medium
# 9      Morning 2016-07-11     7:25:00 AM    00:39:00   Medium
#
# Insight 1
#
#               Status  Total_Requests
# 0     Trip Completed            2831
# 1  No Cars Available            2650
# 2          Cancelled            1264
#
# Insight 2
#
#    Total_Requests  Trip_Completed  Trip_Completion_Rercent
# 0            6745            2831                    41.97
#
# Insight 3
#
#     Day Category  Airport  City
# 0  Early Morning      117   178
# 1        Morning      565  1952
# 2      Afternoon      339   471
# 3        Evening     1457   436
# 4          Night      624   323
# 5     Late Night      136   147
#
# Insight 4
#
#   Pickup point             Status  Total
# 0      Airport     Trip Completed   1327
# 1      Airport          Cancelled    198
# 2      Airport  No Cars Available   1713
# 3         City     Trip Completed   1504
# 4         City          Cancelled   1066
# 5         City  No Cars Available    937
#
# Insight 5
#
#     Day Category  Gaps
# 0        Evening  1127
# 1        Morning   512
# 2          Night   484
# 3      Afternoon   228
# 4     Late Night   169
# 5  Early Morning   130
#
# Insight 6
#
#   Pickup point Distance  Trip_Count
# 0      Airport   Medium         824
# 1      Airport      Far         394
# 2      Airport     Near         109
# 3         City   Medium         918
# 4         City      Far         483
# 5         City     Near         103
#
# Insight 7
#
#   Driver id  Airport  City
# 0       225       10     3
# 1         9       10     3
# 2       134        9     5
# 3        80        9     4
# 4        69        8     6
# 5        51        8     5
# 6        27        8     5
# 7       223        8     5
# 8       194        8     4
# 9        85        8     4
#
# Insight 8
#
#   Pickup point  Completed_Trips  Incomplete_Trips  Completion_Rate  \
# 0      Airport             1327              1911            40.98
# 1         City             1504              2003            42.89
#
#    Incompletion_Rate
# 0              59.02
# 1              57.11
#
# Insight 9
#
#   Pickup point  Far  Medium  Near
# 0      Airport  394     824   109
# 1         City  483     918   103
#
# Insight 10
#
#     Day Category  Avg_Time_Minutes
# 0      Afternoon             32.95
# 1        Evening             32.83
# 2  Early Morning             32.67
# 3          Night             31.95
# 4        Morning             31.68
# 5     Late Night             29.37
